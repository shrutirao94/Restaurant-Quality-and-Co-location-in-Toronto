# %%
import csv
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import operator #need this for sorting dicts later
import matplotlib.cm as cm #for colormapping later
from matplotlib.colors import LogNorm
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
pubs_df = pd.read_csv('pubs.csv')
not_restaurant_df = pd.read_csv('not_restaurant.csv')
pubs_df = pubs_df.drop(['city','Unnamed: 0'], 1)
not_restaurant_df = not_restaurant_df.drop(['Unnamed: 0','city','distance'], 1)
final_df = pd.read_csv("table1.csv")
final_df = final_df.drop(['Unnamed: 0'], 1)
final_df.head()
# Out:
#      density  mean_business_rating                  name  rating
# 0   5.888733              3.918919  McCarthy's Irish Pub     4.0
# 1   3.819719              3.895833       Boardwalk Place     3.0
# 2   8.912677              3.660714    The Yellow Griffin     3.0
# 3   9.071832              3.763158           Cabin Fever     4.5
# 4  18.143664              4.052632         Bar Homestand     3.5

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[251]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[252]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[253]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[254]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[255]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[256]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[257]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[258]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[259]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[260]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[261]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[262]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[263]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[264]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[265]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[266]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[267]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[268]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[269]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[270]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[271]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[272]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[273]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[274]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[275]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[276]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[277]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[278]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[279]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[280]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[281]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[282]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[283]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[284]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[285]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[286]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[287]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[288]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[289]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[290]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[291]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[292]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[293]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[294]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[295]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[296]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[297]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[298]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[299]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[300]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[301]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[302]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[303]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[304]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[305]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[306]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[307]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[308]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[309]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[310]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[311]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[312]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[313]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[314]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[315]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[316]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[317]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[318]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[319]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[320]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[321]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[322]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[323]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[324]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[325]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[326]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[327]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[328]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[329]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[330]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[331]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[332]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[333]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[334]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[335]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[336]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[337]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[338]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[339]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[340]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[341]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[342]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[343]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[344]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[345]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[346]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[347]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[301]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
final_df.to_csv("table2.csv")
