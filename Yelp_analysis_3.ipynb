# %%
import csv
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import operator #need this for sorting dicts later
import matplotlib.cm as cm #for colormapping later
from matplotlib.colors import LogNorm
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
pubs_df = pd.read_csv('pubs.csv')
not_restaurant_df = pd.read_csv('not_restaurant.csv')
pubs_df = pubs_df.drop(['city','Unnamed: 0'], 1)
not_restaurant_df = not_restaurant_df.drop(['Unnamed: 0','city','distance'], 1)
final_df = pd.read_csv("table.csv")
final_df = final_df.drop(['Unnamed: 0'], 1)
final_df.head()
# Out:
#      density  mean_business_rating                  name  rating
# 0   5.888733              3.918919  McCarthy's Irish Pub     4.0
# 1   3.819719              3.895833       Boardwalk Place     3.0
# 2   8.912677              3.660714    The Yellow Griffin     3.0
# 3   9.071832              3.763158           Cabin Fever     4.5
# 4  18.143664              4.052632         Bar Homestand     3.5

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[101]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[102]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[103]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[104]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[105]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[106]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[107]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[108]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[109]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[110]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[111]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[112]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[113]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[114]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[115]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[116]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[117]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[118]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[119]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[120]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[121]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[122]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[123]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[124]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[125]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[126]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[127]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[128]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[129]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[130]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[131]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[132]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[133]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[134]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[135]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[136]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[137]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[138]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[139]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[140]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[141]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[142]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[143]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[144]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[145]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[146]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[147]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[148]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[149]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[150]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[151]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[152]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[153]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[154]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[155]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[156]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[157]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[158]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[159]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[160]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[161]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[162]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[163]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[164]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[165]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[166]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[167]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[168]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[169]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[170]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[171]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[172]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[173]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[174]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[175]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[176]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[177]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[178]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[179]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[180]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[181]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[182]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[183]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[184]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[185]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[186]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[187]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[188]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[189]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[190]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[191]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[192]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[193]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[194]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[195]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[196]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[197]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[198]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[199]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[200]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[201]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[202]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[203]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[204]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[205]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[206]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[207]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[208]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[209]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[210]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[211]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[212]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[213]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[214]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[215]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[216]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[217]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[218]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[219]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[220]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[221]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[222]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[223]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[224]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[225]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[226]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[227]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[228]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean()
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[229]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[230]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[231]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[232]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[233]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[234]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[235]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[236]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[237]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[238]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[239]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[240]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[241]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[242]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[243]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[244]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[245]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[246]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[247]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[248]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[249]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
df = pd.DataFrame()

pubs1_df = pubs_df.iloc[[250]]
pubs1_df

df['LAT_rad'], df['LON_rad'] = np.radians(not_restaurant_df['latitude']), np.radians(not_restaurant_df['longitude'])
df['dLON'] = df['LON_rad'] - math.radians(pubs1_df['longitude'])
df['dLAT'] = df['LAT_rad'] - math.radians(pubs1_df['latitude'])

# using heaversine's formula:
not_restaurant_df['distance'] = 6367 * 2 * np.arcsin(np.sqrt(np.sin(df['dLAT']/2)**2 + math.cos(math.radians(37.2175900)) * np.cos(df['LAT_rad']) * np.sin(df['dLON']/2)**2))
not_restaurant_df = not_restaurant_df.drop_duplicates(subset=['name','postal_code','review_count', 'distance'], keep=False)
measure_1 = not_restaurant_df
measure_1 = measure_1.loc[not_restaurant_df['distance'] <=1.0]
mean1 = measure_1['stars'].mean() 
density = (measure_1['stars'].count())/ (2*math.pi*1.0*1.0)


final_df = final_df.append({'name': pubs1_df['name'].item(), 'rating': pubs1_df['stars'].item(), 'mean_business_rating': mean1, "density": density}, ignore_index=True)

# %%
final_df.to_csv("table1.csv")
